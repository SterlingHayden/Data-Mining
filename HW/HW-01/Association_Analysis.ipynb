# %% [markdown]
# ## Objective
# Eats4Life would like to update its menu to include wine suggestions with each of its main entrees (defined by the meat selection). The owner would like to take a Data Analytics approach and explore data he collected over the past several years on main courses (meat) and wine that was ordered with it. Eats4Life is open to listing more than one wine for each main entree, but only if the data supports it. The scope of services requested includes:
#
# - Summary information on the main entrees (meat)
# - Wine suggestion(s) for **each** main entree along with supporting information as to why this (these) wines are suggested for the entrée (if you have no suggested wine for a given entrée, provide information as to why this is your suggestion)
# - Any other information of interest in terms of customer order habits
#
# ## Data Provided
# The dataset `orderData.csv` has three columns:
#
# - `orderNo` – identifies each table/party that sat at the restaurant
# - `seatNo` – indicates which seat at the table ordered each meal
# - `item` – the item that was ordered
#
# The data has been cleaned, so that each order contains three items per individual: a meat, a side, and a wine.

# %%
import pandas as pd
from mlxtend.frequent_patterns import association_rules
from mlxtend.frequent_patterns import apriori

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sjsimmo2/DataMining-Fall/refs/heads/master/orderData.csv')

# %%
print(df.shape)
df.head()
# Out:
# (228699, 3)
#    orderNo  seatNo                        item
# 0   122314       1                      Salmon
# 1   122314       1  Oyster Bay Sauvignon Blanc
# 2   122314       1                   Bean Trio
# 3   122314       2                   Pork Chop
# 4   122314       2            Three Rivers Red

# %%
df['item'].value_counts()
# Out:
# item
# Seasonal Veg                          14574
# Filet Mignon                          13407
# Sea Bass                              12302
# Duckhorn Chardonnay                   11723
# Bean Trio                             11696
# Roasted Root Veg                      11323
# Pork Tenderloin                       11138
# Pork Chop                             10976
# Warm Goat Salad                       10605
# Adelsheim Pinot Noir                  10308
# Roasted Potatoes                       9847
# Salmon                                 9336
# Caesar Salad                           9168
# Mashed Potatoes                        9020
# Blackstone Merlot                      8485
# Total Recall Chardonnay                8012
# Duck Breast                            7915
# Single Vineyard Malbec                 7791
# Swordfish                              7439
# Innocent Bystander Sauvignon Blanc     6397
# Oyster Bay Sauvignon Blanc             4815
# Echeverria Gran Syrah                  4600
# Brancott Pinot Grigio                  4478
# Roast Chicken                          3720
# Cantina Pinot Bianco                   3594
# Louis Rouge                            2580
# Helben Blanc                           2032
# Three Rivers Red                       1418
# Name: count, dtype: int64

# %%
meats = [
    "Filet Mignon",
    "Sea Bass",
    "Pork Tenderloin",
    "Pork Chop",
    "Salmon",
    "Duck Breast",
    "Swordfish",
    "Roast Chicken"
]

sides = [
    "Seasonal Veg",
    "Bean Trio",
    "Roasted Root Veg",
    "Warm Goat Salad",
    "Roasted Potatoes",
    "Caesar Salad",
    "Mashed Potatoes"
]

wines = [
    "Duckhorn Chardonnay",
    "Adelsheim Pinot Noir",
    "Blackstone Merlot",
    "Total Recall Chardonnay",
    "Single Vineyard Malbec",
    "Innocent Bystander Sauvignon Blanc",
    "Oyster Bay Sauvignon Blanc",
    "Echeverria Gran Syrah",
    "Brancott Pinot Grigio",
    "Cantina Pinot Bianco",
    "Louis Rouge",
    "Helben Blanc",
    "Three Rivers Red"
]

# %% [markdown]
# ## Data Processing

# %% [markdown]
# ### Meat + Wine

# %%
#create a df with only the meat and wine pairings
df_meat_wine = df[df['item'].isin(meats + wines)]

#create a dummy varriable for each item
df_1 = pd.get_dummies(df_meat_wine["item"])*1

#add the original order number to the new df
df_1["orderNo"] = df_meat_wine["orderNo"]
#add the original seat number to the new df
df_1['seatNo'] = df_meat_wine['seatNo']
#df_1["order_seatNo"] = df['orderNo'].astype(str) + "_" + df['seatNo'].astype(str)

#group by orderNo and seatNo, then calculates the maximum value for each col
df_1 = df_1.groupby(['orderNo', 'seatNo']).max()

#convert the dummy vars back to boolean 
preprocessed_df = df_1.map(bool)

preprocessed_df.head()
# Out:
#                 Adelsheim Pinot Noir  Blackstone Merlot  \
# orderNo seatNo
# 122314  1                      False              False
#         2                      False              False
#         3                      False              False
#         4                      False              False
#         5                      False              False
#
#                 Brancott Pinot Grigio  Cantina Pinot Bianco  Duck Breast  \
# orderNo seatNo
# 122314  1                       False                 False        False
#         2                       False                 False        False
#         3                       False                 False        False
#         4                       False                 False        False
#         5                       False                 False         True
#
#                 Duckhorn Chardonnay  Echeverria Gran Syrah  Filet Mignon  \
# orderNo seatNo
# 122314  1                     False                  False         False
#         2                     False                  False         False
#         3                     False                  False         False
#         4                     False                  False         False
#         5                     False                  False         False
#
#                 Helben Blanc  Innocent Bystander Sauvignon Blanc  ...  \
# orderNo seatNo                                                    ...
# 122314  1              False                               False  ...
#         2              False                               False  ...
#         3              False                               False  ...
#         4              False                               False  ...
#         5              False                                True  ...
#
#                 Oyster Bay Sauvignon Blanc  Pork Chop  Pork Tenderloin  \
# orderNo seatNo
# 122314  1                             True      False            False
#         2                            False       True            False
#         3                             True      False            False
#         4                            False      False            False
#         5                            False      False            False
#
#                 Roast Chicken  Salmon  Sea Bass  Single Vineyard Malbec  \
# orderNo seatNo
# 122314  1               False    True     False                   False
#         2               False   False     False                   False
#         3               False   False      True                   False
#         4               False   False      True                   False
#         5               False   False     False                   False
#
#                 Swordfish  Three Rivers Red  Total Recall Chardonnay
# orderNo seatNo
# 122314  1           False             False                    False
#         2           False              True                    False
#         3           False             False                    False
#         4           False             False                     True
#         5           False             False                    False
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Meat + Side

# %%
#create a df with only the meat and side pairings
df_meat_side = df[df['item'].isin(meats + sides)]

#create a dummy varriable for each item
df_2 = pd.get_dummies(df_meat_side["item"])*1

#add the original order number to the new df
df_2["orderNo"] = df_meat_side["orderNo"]
#add the original seat number to the new df
df_2['seatNo'] = df_meat_side['seatNo']

#group by orderNo and seatNo, then calculates the maximum value for each col
df_2 = df_2.groupby(['orderNo', 'seatNo']).max()

#convert the dummy vars back to boolean 
preprocessed_sides_df = df_2.map(bool)

preprocessed_sides_df.head()
# Out:
#                 Bean Trio  Caesar Salad  Duck Breast  Filet Mignon  \
# orderNo seatNo
# 122314  1            True         False        False         False
#         2           False          True        False         False
#         3           False          True        False         False
#         4            True         False        False         False
#         5            True         False         True         False
#
#                 Mashed Potatoes  Pork Chop  Pork Tenderloin  Roast Chicken  \
# orderNo seatNo
# 122314  1                 False      False            False          False
#         2                 False       True            False          False
#         3                 False      False            False          False
#         4                 False      False            False          False
#         5                 False      False            False          False
#
#                 Roasted Potatoes  Roasted Root Veg  Salmon  Sea Bass  \
# orderNo seatNo
# 122314  1                  False             False    True     False
#         2                  False             False   False     False
#         3                  False             False   False      True
#         4                  False             False   False      True
#         5                  False             False   False     False
#
#                 Seasonal Veg  Swordfish  Warm Goat Salad
# orderNo seatNo
# 122314  1              False      False            False
#         2              False      False            False
#         3              False      False            False
#         4              False      False            False
#         5              False      False            False

# %% [markdown]
# ### Meat + Side + Wine

# %%
#create a dummy varriable for each item
df_1 = pd.get_dummies(df["item"])*1

#add the original order number to the new df
df_1["orderNo"] = df["orderNo"]
#add the original seat number to the new df
df_1['seatNo'] = df['seatNo']

#group by orderNo and seatNo, then calculates the maximum value for each col
df_1 = df_1.groupby(['orderNo', 'seatNo']).max()

#convert the dummy vars back to boolean 
preprocessed_df_all = df_1.map(bool)

preprocessed_df.head()
# Out:
#                 Adelsheim Pinot Noir  Blackstone Merlot  \
# orderNo seatNo
# 122314  1                      False              False
#         2                      False              False
#         3                      False              False
#         4                      False              False
#         5                      False              False
#
#                 Brancott Pinot Grigio  Cantina Pinot Bianco  Duck Breast  \
# orderNo seatNo
# 122314  1                       False                 False        False
#         2                       False                 False        False
#         3                       False                 False        False
#         4                       False                 False        False
#         5                       False                 False         True
#
#                 Duckhorn Chardonnay  Echeverria Gran Syrah  Filet Mignon  \
# orderNo seatNo
# 122314  1                     False                  False         False
#         2                     False                  False         False
#         3                     False                  False         False
#         4                     False                  False         False
#         5                     False                  False         False
#
#                 Helben Blanc  Innocent Bystander Sauvignon Blanc  ...  \
# orderNo seatNo                                                    ...
# 122314  1              False                               False  ...
#         2              False                               False  ...
#         3              False                               False  ...
#         4              False                               False  ...
#         5              False                                True  ...
#
#                 Oyster Bay Sauvignon Blanc  Pork Chop  Pork Tenderloin  \
# orderNo seatNo
# 122314  1                             True      False            False
#         2                            False       True            False
#         3                             True      False            False
#         4                            False      False            False
#         5                            False      False            False
#
#                 Roast Chicken  Salmon  Sea Bass  Single Vineyard Malbec  \
# orderNo seatNo
# 122314  1               False    True     False                   False
#         2               False   False     False                   False
#         3               False   False      True                   False
#         4               False   False      True                   False
#         5               False   False     False                   False
#
#                 Swordfish  Three Rivers Red  Total Recall Chardonnay
# orderNo seatNo
# 122314  1           False             False                    False
#         2           False              True                    False
#         3           False             False                    False
#         4           False             False                     True
#         5           False             False                    False
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Apriori Algorithm
#
# ### Support
# - **Definition**: Support represents how frequently the combination of antecedent (meat) and consequent (wine) appears together in the dataset.
# - **Interpretation**: It tells you the proportion of transactions (orders) where both the specified meat and wine were ordered together.
#
# ### Confidence
# - **Definition**: Confidence measures how often the wine (consequent) is purchased when the meat (antecedent) is purchased.
# - **Interpretation**: It indicates the likelihood that if a customer orders a specific meat, they will also order the specific wine. High confidence means that the wine is frequently bought with the meat.
#
# ### Lift
# - **Definition**: Lift measures how much more likely a customer is to buy a particular wine when they've bought a particular meat, compared to buying that wine independently of the meat.
# - **Interpretation**: Lift tells you if there is a strong positive association between a specific meat and wine. A lift value greater than 1 indicates that the wine is more likely to be bought with the meat than randomly. A lift value less than 1 means they are less likely to be bought together than expected by chance.

# %% [markdown]
# ### Meat and Wine Pairings Only

# %%
#apriori algorithm
food_wine_assoc = apriori(preprocessed_df, min_support = 0.001, use_colnames = True)

#association rules
out_rules = association_rules(food_wine_assoc,metric = "confidence", min_threshold = 0.1)

#select columns from the output
out_rules2=out_rules[['antecedents','consequents','support','confidence','lift']]

out_rules2
# Out:
#                   antecedents                consequents   support  \
# 0               (Duck Breast)     (Adelsheim Pinot Noir)  0.016476
# 1      (Adelsheim Pinot Noir)              (Duck Breast)  0.016476
# 2              (Filet Mignon)     (Adelsheim Pinot Noir)  0.049650
# 3      (Adelsheim Pinot Noir)             (Filet Mignon)  0.049650
# 4      (Adelsheim Pinot Noir)                (Pork Chop)  0.013826
# ..                        ...                        ...       ...
# 80         (Three Rivers Red)                 (Sea Bass)  0.004854
# 81  (Total Recall Chardonnay)                 (Sea Bass)  0.015990
# 82         (Three Rivers Red)                (Swordfish)  0.001928
# 83  (Total Recall Chardonnay)                (Swordfish)  0.017447
# 84                (Swordfish)  (Total Recall Chardonnay)  0.017447
#
#     confidence      lift
# 0     0.158686  1.173565
# 1     0.121847  1.173565
# 2     0.282315  2.087867
# 3     0.367191  2.087867
# 4     0.102251  0.710175
# ..         ...       ...
# 80    0.260931  1.616936
# 81    0.152147  0.942823
# 82    0.103667  1.062355
# 83    0.166001  1.701136
# 84    0.178787  1.701136
#
# [85 rows x 5 columns]

# %% [markdown]
# Lets only looking at meats as antecedents and wines as consequents

# %%
#filtering for antecedents to be meats only
meats_antecedents = out_rules2[out_rules2['antecedents'].apply(lambda x: list(x)[0] in meats)]
#sort by lift
meats_antecedents.sort_values(by='lift', ascending=False)
# Out:
#           antecedents                           consequents   support  \
# 58        (Pork Chop)                         (Louis Rouge)  0.016555
# 9      (Filet Mignon)                   (Blackstone Merlot)  0.062729
# 62    (Roast Chicken)          (Oyster Bay Sauvignon Blanc)  0.009471
# 12    (Roast Chicken)               (Brancott Pinot Grigio)  0.008448
# 7       (Duck Breast)                   (Blackstone Merlot)  0.032886
# 53         (Sea Bass)  (Innocent Bystander Sauvignon Blanc)  0.036651
# 18        (Swordfish)               (Brancott Pinot Grigio)  0.014705
# 63           (Salmon)          (Oyster Bay Sauvignon Blanc)  0.018365
# 43     (Filet Mignon)               (Echeverria Gran Syrah)  0.024648
# 21           (Salmon)                (Cantina Pinot Bianco)  0.013328
# 67        (Swordfish)          (Oyster Bay Sauvignon Blanc)  0.013905
# 5   (Pork Tenderloin)                (Adelsheim Pinot Noir)  0.043734
# 2      (Filet Mignon)                (Adelsheim Pinot Noir)  0.049650
# 45     (Filet Mignon)              (Single Vineyard Malbec)  0.037228
# 50    (Roast Chicken)  (Innocent Bystander Sauvignon Blanc)  0.008094
# 76    (Roast Chicken)             (Total Recall Chardonnay)  0.009917
# 15         (Sea Bass)               (Brancott Pinot Grigio)  0.016856
# 72  (Pork Tenderloin)              (Single Vineyard Malbec)  0.026117
# 84        (Swordfish)             (Total Recall Chardonnay)  0.017447
# 74  (Pork Tenderloin)             (Total Recall Chardonnay)  0.026052
# 78           (Salmon)             (Total Recall Chardonnay)  0.021605
# 55        (Swordfish)  (Innocent Bystander Sauvignon Blanc)  0.013642
# 68        (Pork Chop)              (Single Vineyard Malbec)  0.024399
# 39         (Sea Bass)                 (Duckhorn Chardonnay)  0.040232
# 33  (Pork Tenderloin)                 (Duckhorn Chardonnay)  0.035510
# 32        (Pork Chop)                 (Duckhorn Chardonnay)  0.033004
# 51           (Salmon)  (Innocent Bystander Sauvignon Blanc)  0.014338
# 0       (Duck Breast)                (Adelsheim Pinot Noir)  0.016476
# 41        (Swordfish)                 (Duckhorn Chardonnay)  0.017538
# 29      (Duck Breast)              (Single Vineyard Malbec)  0.010533
# 36           (Salmon)                 (Duckhorn Chardonnay)  0.018207
# 35    (Roast Chicken)                 (Duckhorn Chardonnay)  0.005982
#
#     confidence      lift
# 58    0.114978  3.397336
# 9     0.356679  3.204565
# 62    0.194086  3.072847
# 12    0.173118  2.947147
# 7     0.316740  2.845736
# 53    0.227118  2.706558
# 18    0.150692  2.565370
# 63    0.149957  2.374181
# 43    0.140151  2.322632
# 21    0.108826  2.308330
# 67    0.142492  2.255994
# 5     0.299336  2.213742
# 2     0.282315  2.087867
# 45    0.211680  2.071241
# 50    0.165860  1.976555
# 76    0.203226  1.933664
# 15    0.104455  1.778223
# 72    0.178757  1.749097
# 84    0.178787  1.701136
# 74    0.178308  1.696579
# 78    0.176414  1.678552
# 55    0.139804  1.666040
# 68    0.169461  1.658130
# 39    0.249309  1.621221
# 33    0.243042  1.580466
# 32    0.229227  1.490633
# 51    0.117074  1.395166
# 0     0.158686  1.173565
# 41    0.179728  1.168749
# 29    0.101453  0.992692
# 36    0.148672  0.966792
# 35    0.122581  0.797124

# %% [markdown]
# Lets see what meat and wine pairings have the highest lift values.
# I'm picking lift as, lift controls for the popularity of both items individually. Even if a wine is popular, a high lift means it’s more likely to be chosen because of the meat rather than general popularity.

# %%
#finding the highest lift meat and wine pairing
meats_antecedents.loc[meats_antecedents.groupby('antecedents')['lift'].idxmax()].sort_values(by='lift', ascending=False)
# Out:
#           antecedents                           consequents   support  \
# 58        (Pork Chop)                         (Louis Rouge)  0.016555
# 9      (Filet Mignon)                   (Blackstone Merlot)  0.062729
# 62    (Roast Chicken)          (Oyster Bay Sauvignon Blanc)  0.009471
# 7       (Duck Breast)                   (Blackstone Merlot)  0.032886
# 53         (Sea Bass)  (Innocent Bystander Sauvignon Blanc)  0.036651
# 18        (Swordfish)               (Brancott Pinot Grigio)  0.014705
# 63           (Salmon)          (Oyster Bay Sauvignon Blanc)  0.018365
# 5   (Pork Tenderloin)                (Adelsheim Pinot Noir)  0.043734
#
#     confidence      lift
# 58    0.114978  3.397336
# 9     0.356679  3.204565
# 62    0.194086  3.072847
# 7     0.316740  2.845736
# 53    0.227118  2.706558
# 18    0.150692  2.565370
# 63    0.149957  2.374181
# 5     0.299336  2.213742

# %% [markdown]
# Lets take a look at the top 3 wines (based on their lift values) for each type of meat.

# %%
top3 = meats_antecedents.groupby('antecedents', group_keys=False).apply(lambda x: x.nlargest(3, 'lift')).sort_values(by=['antecedents', 'lift'], ascending=[True, False])

top3.to_csv('Top3_Wines_By_Meat')

top3
# Out:
# C:\Users\Sterling Hayden\AppData\Local\Temp\ipykernel_6572\1269758349.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top3 = meats_antecedents.groupby('antecedents', group_keys=False).apply(lambda x: x.nlargest(3, 'lift')).sort_values(by=['antecedents', 'lift'], ascending=[True, False])
#           antecedents                           consequents   support  \
# 7       (Duck Breast)                   (Blackstone Merlot)  0.032886
# 0       (Duck Breast)                (Adelsheim Pinot Noir)  0.016476
# 29      (Duck Breast)              (Single Vineyard Malbec)  0.010533
# 9      (Filet Mignon)                   (Blackstone Merlot)  0.062729
# 43     (Filet Mignon)               (Echeverria Gran Syrah)  0.024648
# 2      (Filet Mignon)                (Adelsheim Pinot Noir)  0.049650
# 5   (Pork Tenderloin)                (Adelsheim Pinot Noir)  0.043734
# 72  (Pork Tenderloin)              (Single Vineyard Malbec)  0.026117
# 74  (Pork Tenderloin)             (Total Recall Chardonnay)  0.026052
# 62    (Roast Chicken)          (Oyster Bay Sauvignon Blanc)  0.009471
# 12    (Roast Chicken)               (Brancott Pinot Grigio)  0.008448
# 50    (Roast Chicken)  (Innocent Bystander Sauvignon Blanc)  0.008094
# 53         (Sea Bass)  (Innocent Bystander Sauvignon Blanc)  0.036651
# 15         (Sea Bass)               (Brancott Pinot Grigio)  0.016856
# 39         (Sea Bass)                 (Duckhorn Chardonnay)  0.040232
# 18        (Swordfish)               (Brancott Pinot Grigio)  0.014705
# 67        (Swordfish)          (Oyster Bay Sauvignon Blanc)  0.013905
# 84        (Swordfish)             (Total Recall Chardonnay)  0.017447
# 63           (Salmon)          (Oyster Bay Sauvignon Blanc)  0.018365
# 21           (Salmon)                (Cantina Pinot Bianco)  0.013328
# 78           (Salmon)             (Total Recall Chardonnay)  0.021605
# 58        (Pork Chop)                         (Louis Rouge)  0.016555
# 68        (Pork Chop)              (Single Vineyard Malbec)  0.024399
# 32        (Pork Chop)                 (Duckhorn Chardonnay)  0.033004
#
#     confidence      lift
# 7     0.316740  2.845736
# 0     0.158686  1.173565
# 29    0.101453  0.992692
# 9     0.356679  3.204565
# 43    0.140151  2.322632
# 2     0.282315  2.087867
# 5     0.299336  2.213742
# 72    0.178757  1.749097
# 74    0.178308  1.696579
# 62    0.194086  3.072847
# 12    0.173118  2.947147
# 50    0.165860  1.976555
# 53    0.227118  2.706558
# 15    0.104455  1.778223
# 39    0.249309  1.621221
# 18    0.150692  2.565370
# 67    0.142492  2.255994
# 84    0.178787  1.701136
# 63    0.149957  2.374181
# 21    0.108826  2.308330
# 78    0.176414  1.678552
# 58    0.114978  3.397336
# 68    0.169461  1.658130
# 32    0.229227  1.490633

# %% [markdown]
# ### Meat and Side Pairings Only

# %%
#apriori algorithm
food_assoc = apriori(preprocessed_sides_df, min_support = 0.001, use_colnames = True)

#association rules
out_rules_side = association_rules(food_assoc,metric = "confidence", min_threshold = 0.1)

#select columns from the output
out_rules2_side=out_rules_side[['antecedents','consequents','support','confidence','lift']]

out_rules2_side
# Out:
#           antecedents        consequents   support  confidence      lift
# 0       (Duck Breast)        (Bean Trio)  0.018129    0.174605  1.138054
# 1         (Bean Trio)      (Duck Breast)  0.018129    0.118160  1.138054
# 2      (Filet Mignon)        (Bean Trio)  0.030079    0.171030  1.114752
# 3         (Bean Trio)     (Filet Mignon)  0.030079    0.196050  1.114752
# 4         (Pork Chop)        (Bean Trio)  0.024543    0.170463  1.111054
# ..                ...                ...       ...         ...       ...
# 84  (Warm Goat Salad)         (Sea Bass)  0.027718    0.199246  1.234685
# 85         (Sea Bass)  (Warm Goat Salad)  0.027718    0.171761  1.234685
# 86        (Swordfish)     (Seasonal Veg)  0.017512    0.179460  0.938709
# 87  (Warm Goat Salad)        (Swordfish)  0.016712    0.120132  1.231083
# 88        (Swordfish)  (Warm Goat Salad)  0.016712    0.171260  1.231083
#
# [89 rows x 5 columns]

# %%
#filtering for antecedents to be meats only
meats_antecedents_2 = out_rules2_side[out_rules2_side['antecedents'].apply(lambda x: list(x)[0] in meats)]
#sort by lift
meats_antecedents_2.sort_values(by='lift', ascending=False)
# Out:
#           antecedents         consequents   support  confidence      lift
# 18  (Pork Tenderloin)      (Caesar Salad)  0.032401    0.221763  1.843988
# 65    (Roast Chicken)  (Roasted Potatoes)  0.009576    0.196237  1.519214
# 45    (Roast Chicken)   (Mashed Potatoes)  0.008487    0.173925  1.469934
# 61  (Pork Tenderloin)      (Seasonal Veg)  0.036402    0.249147  1.303227
# 7            (Salmon)         (Bean Trio)  0.023717    0.193659  1.262244
# 85         (Sea Bass)   (Warm Goat Salad)  0.027718    0.171761  1.234685
# 88        (Swordfish)   (Warm Goat Salad)  0.016712    0.171260  1.231083
# 72           (Salmon)  (Roasted Root Veg)  0.021893    0.178770  1.203586
# 59  (Pork Tenderloin)  (Roasted Potatoes)  0.022208    0.152002  1.176762
# 46           (Salmon)   (Mashed Potatoes)  0.017027    0.139032  1.175034
# 0       (Duck Breast)         (Bean Trio)  0.018129    0.174605  1.138054
# 2      (Filet Mignon)         (Bean Trio)  0.030079    0.171030  1.114752
# 4         (Pork Chop)         (Bean Trio)  0.024543    0.170463  1.111054
# 54        (Pork Chop)  (Roasted Root Veg)  0.023756    0.164996  1.110851
# 11        (Swordfish)         (Bean Trio)  0.016528    0.169378  1.103981
# 26      (Duck Breast)  (Roasted Root Veg)  0.016856    0.162350  1.093034
# 15     (Filet Mignon)      (Caesar Salad)  0.022877    0.130081  1.081641
# 9          (Sea Bass)         (Bean Trio)  0.026629    0.165014  1.075539
# 36     (Filet Mignon)  (Roasted Root Veg)  0.028006    0.159245  1.072131
# 43  (Pork Tenderloin)   (Mashed Potatoes)  0.018378    0.125786  1.063084
# 74         (Sea Bass)  (Roasted Root Veg)  0.025186    0.156072  1.050768
# 77        (Swordfish)  (Roasted Root Veg)  0.015020    0.153919  1.036269
# 81           (Salmon)   (Warm Goat Salad)  0.017565    0.143423  1.030984
# 24      (Duck Breast)  (Roasted Potatoes)  0.013616    0.131143  1.015279
# 52        (Pork Chop)  (Roasted Potatoes)  0.018824    0.130740  1.012155
# 42        (Pork Chop)   (Mashed Potatoes)  0.017092    0.118714  1.003314
# 78           (Salmon)      (Seasonal Veg)  0.023468    0.191624  1.002337
# 34     (Filet Mignon)  (Roasted Potatoes)  0.022602    0.128515  0.994930
# 70         (Sea Bass)  (Roasted Potatoes)  0.020424    0.126565  0.979833
# 37     (Filet Mignon)      (Seasonal Veg)  0.032899    0.187066  0.978499
# 28      (Duck Breast)      (Seasonal Veg)  0.019335    0.186229  0.974116
# 6     (Roast Chicken)         (Bean Trio)  0.007175    0.147043  0.958407
# 86        (Swordfish)      (Seasonal Veg)  0.017512    0.179460  0.938709
# 58        (Pork Chop)   (Warm Goat Salad)  0.018706    0.129920  0.933916
# 30      (Duck Breast)   (Warm Goat Salad)  0.013485    0.129880  0.933629
# 63  (Pork Tenderloin)   (Warm Goat Salad)  0.018889    0.129287  0.929368
# 71        (Swordfish)  (Roasted Potatoes)  0.011701    0.119909  0.928302
# 55        (Pork Chop)      (Seasonal Veg)  0.025527    0.177296  0.927391
# 32     (Filet Mignon)   (Mashed Potatoes)  0.019165    0.108973  0.920990
# 23      (Duck Breast)   (Mashed Potatoes)  0.011294    0.108781  0.919367
# 66    (Roast Chicken)  (Roasted Root Veg)  0.006611    0.135484  0.912156
# 82         (Sea Bass)      (Seasonal Veg)  0.027809    0.172330  0.901414
# 17        (Pork Chop)      (Caesar Salad)  0.015531    0.107872  0.896966
# 13      (Duck Breast)      (Caesar Salad)  0.011111    0.107012  0.889817
# 67    (Roast Chicken)      (Seasonal Veg)  0.008225    0.168548  0.881635
# 50        (Swordfish)   (Mashed Potatoes)  0.010140    0.103912  0.878216
# 49         (Sea Bass)   (Mashed Potatoes)  0.016738    0.103723  0.876620
# 21         (Sea Bass)      (Caesar Salad)  0.016869    0.104536  0.869228
# 68    (Roast Chicken)   (Warm Goat Salad)  0.005798    0.118817  0.854106
# 22        (Swordfish)      (Caesar Salad)  0.009969    0.102164  0.849508
# 40     (Filet Mignon)   (Warm Goat Salad)  0.020241    0.115089  0.827307

# %%
#finding the highest lift meat and wine pairing
meats_antecedents_2.loc[meats_antecedents_2.groupby('antecedents')['lift'].idxmax()].sort_values(by='lift', ascending=False)
# Out:
#           antecedents         consequents   support  confidence      lift
# 18  (Pork Tenderloin)      (Caesar Salad)  0.032401    0.221763  1.843988
# 65    (Roast Chicken)  (Roasted Potatoes)  0.009576    0.196237  1.519214
# 7            (Salmon)         (Bean Trio)  0.023717    0.193659  1.262244
# 85         (Sea Bass)   (Warm Goat Salad)  0.027718    0.171761  1.234685
# 88        (Swordfish)   (Warm Goat Salad)  0.016712    0.171260  1.231083
# 0       (Duck Breast)         (Bean Trio)  0.018129    0.174605  1.138054
# 2      (Filet Mignon)         (Bean Trio)  0.030079    0.171030  1.114752
# 4         (Pork Chop)         (Bean Trio)  0.024543    0.170463  1.111054

# %% [markdown]
# ### Meat + Side + Wine

# %%
#apriori algorithm
food_side_wine_assoc = apriori(preprocessed_df_all, min_support = 0.001, use_colnames = True)

#association rules
out_rules_all = association_rules(food_side_wine_assoc,metric = "confidence", min_threshold = 0.1)

#select columns from the output
out_rules2_all = out_rules_all[['antecedents','consequents','support','confidence','lift']]

out_rules2_all
# Out:
#                                      antecedents                consequents  \
# 0                                    (Bean Trio)     (Adelsheim Pinot Noir)
# 1                         (Adelsheim Pinot Noir)                (Bean Trio)
# 2                                 (Caesar Salad)     (Adelsheim Pinot Noir)
# 3                         (Adelsheim Pinot Noir)             (Caesar Salad)
# 4                                  (Duck Breast)     (Adelsheim Pinot Noir)
# ...                                          ...                        ...
# 1014        (Swordfish, Total Recall Chardonnay)             (Seasonal Veg)
# 1015                   (Swordfish, Seasonal Veg)  (Total Recall Chardonnay)
# 1016  (Warm Goat Salad, Total Recall Chardonnay)                (Swordfish)
# 1017                (Warm Goat Salad, Swordfish)  (Total Recall Chardonnay)
# 1018        (Swordfish, Total Recall Chardonnay)          (Warm Goat Salad)
#
#        support  confidence      lift
# 0     0.017919    0.116792  0.863738
# 1     0.017919    0.132518  0.863738
# 2     0.020516    0.170593  1.261626
# 3     0.020516    0.151727  1.261626
# 4     0.016476    0.158686  1.173565
# ...        ...         ...       ...
# 1014  0.002873    0.164662  0.861305
# 1015  0.002873    0.164045  1.560863
# 1016  0.003043    0.196610  2.014812
# 1017  0.003043    0.182104  1.732689
# 1018  0.003043    0.174436  1.253917
#
# [1019 rows x 5 columns]

# %% [markdown]
# Lets see what pairings have the highest lift values

# %%
out_rules2_all.sort_values(by='lift', ascending=False)
# Out:
#                                         antecedents      consequents  \
# 892  (Roasted Potatoes, Oyster Bay Sauvignon Blanc)  (Roast Chicken)
# 524       (Roasted Potatoes, Brancott Pinot Grigio)  (Roast Chicken)
# 861   (Mashed Potatoes, Oyster Bay Sauvignon Blanc)  (Roast Chicken)
# 509        (Mashed Potatoes, Brancott Pinot Grigio)  (Roast Chicken)
# 851                 (Louis Rouge, Roasted Root Veg)      (Pork Chop)
# ..                                              ...              ...
# 339         (Mashed Potatoes, Adelsheim Pinot Noir)      (Pork Chop)
# 613         (Caesar Salad, Total Recall Chardonnay)       (Sea Bass)
# 10                           (Adelsheim Pinot Noir)      (Pork Chop)
# 344        (Roasted Potatoes, Adelsheim Pinot Noir)      (Pork Chop)
# 226                       (Total Recall Chardonnay)      (Pork Chop)
#
#       support  confidence      lift
# 892  0.001863    0.249561  5.114182
# 524  0.001718    0.223932  4.588973
# 861  0.001732    0.208531  4.273368
# 509  0.001364    0.192237  3.939455
# 851  0.002873    0.515294  3.578937
# ..        ...         ...       ...
# 339  0.001600    0.105172  0.730467
# 613  0.001456    0.116109  0.719503
# 10   0.013826    0.102251  0.710175
# 344  0.001810    0.100364  0.697068
# 226  0.010547    0.100349  0.696970
#
# [1019 rows x 5 columns]

# %% [markdown]
# #### consequents = meats

# %%
#filtering for consequents to be meats only
meats_consequents_all = out_rules2_all[out_rules2_all['consequents'].apply(lambda x: list(x)[0] in meats)]
#sort by lift
meats_consequents_all.sort_values(by='lift', ascending=False)
# Out:
#                                         antecedents      consequents  \
# 892  (Roasted Potatoes, Oyster Bay Sauvignon Blanc)  (Roast Chicken)
# 524       (Roasted Potatoes, Brancott Pinot Grigio)  (Roast Chicken)
# 861   (Mashed Potatoes, Oyster Bay Sauvignon Blanc)  (Roast Chicken)
# 509        (Mashed Potatoes, Brancott Pinot Grigio)  (Roast Chicken)
# 851                 (Louis Rouge, Roasted Root Veg)      (Pork Chop)
# ..                                              ...              ...
# 339         (Mashed Potatoes, Adelsheim Pinot Noir)      (Pork Chop)
# 613         (Caesar Salad, Total Recall Chardonnay)       (Sea Bass)
# 10                           (Adelsheim Pinot Noir)      (Pork Chop)
# 344        (Roasted Potatoes, Adelsheim Pinot Noir)      (Pork Chop)
# 226                       (Total Recall Chardonnay)      (Pork Chop)
#
#       support  confidence      lift
# 892  0.001863    0.249561  5.114182
# 524  0.001718    0.223932  4.588973
# 861  0.001732    0.208531  4.273368
# 509  0.001364    0.192237  3.939455
# 851  0.002873    0.515294  3.578937
# ..        ...         ...       ...
# 339  0.001600    0.105172  0.730467
# 613  0.001456    0.116109  0.719503
# 10   0.013826    0.102251  0.710175
# 344  0.001810    0.100364  0.697068
# 226  0.010547    0.100349  0.696970
#
# [346 rows x 5 columns]

# %%
meats_consequents_all.loc[meats_consequents_all.groupby('consequents')['lift'].idxmax()].sort_values(by='lift', ascending=False)
# Out:
#                                            antecedents  \
# 892     (Roasted Potatoes, Oyster Bay Sauvignon Blanc)
# 851                    (Louis Rouge, Roasted Root Veg)
# 470                  (Caesar Salad, Blackstone Merlot)
# 308               (Caesar Salad, Adelsheim Pinot Noir)
# 589  (Caesar Salad, Innocent Bystander Sauvignon Bl...
# 499                                (Blackstone Merlot)
# 485               (Warm Goat Salad, Blackstone Merlot)
# 623            (Mashed Potatoes, Cantina Pinot Bianco)
# 560           (Warm Goat Salad, Brancott Pinot Grigio)
#
#                       consequents   support  confidence      lift
# 892               (Roast Chicken)  0.001863    0.249561  5.114182
# 851                   (Pork Chop)  0.002873    0.515294  3.578937
# 470                (Filet Mignon)  0.008159    0.622623  3.540269
# 308             (Pork Tenderloin)  0.009733    0.474425  3.247155
# 589                    (Sea Bass)  0.004237    0.521809  3.233547
# 499  (Filet Mignon, Seasonal Veg)  0.011557    0.103830  3.156019
# 485                 (Duck Breast)  0.004631    0.323853  3.119179
# 623                      (Salmon)  0.002046    0.362791  2.962363
# 560                   (Swordfish)  0.002505    0.287651  2.947771

# %% [markdown]
# #### consequents = sides

# %%
#filtering for consequents to be sides only
sides_consequents_all = out_rules2_all[out_rules2_all['consequents'].apply(lambda x: list(x)[0] in sides)]
#sort by lift
sides_consequents_all.sort_values(by='lift', ascending=False)
# Out:
#                                     antecedents         consequents   support  \
# 570      (Pork Tenderloin, Duckhorn Chardonnay)      (Caesar Salad)  0.008172
# 606   (Pork Tenderloin, Single Vineyard Malbec)      (Caesar Salad)  0.005929
# 307     (Pork Tenderloin, Adelsheim Pinot Noir)      (Caesar Salad)  0.009733
# 86                            (Pork Tenderloin)      (Caesar Salad)  0.032401
# 609  (Pork Tenderloin, Total Recall Chardonnay)      (Caesar Salad)  0.005614
# ..                                          ...                 ...       ...
# 160                              (Filet Mignon)   (Warm Goat Salad)  0.020241
# 979    (Roast Chicken, Total Recall Chardonnay)  (Roasted Root Veg)  0.001207
# 764       (Echeverria Gran Syrah, Filet Mignon)   (Warm Goat Salad)  0.002755
# 338        (Filet Mignon, Adelsheim Pinot Noir)   (Warm Goat Salad)  0.005300
# 529      (Roast Chicken, Brancott Pinot Grigio)      (Seasonal Veg)  0.001207
#
#      confidence      lift
# 570    0.230144  1.913675
# 606    0.227022  1.887711
# 307    0.222555  1.850575
# 86     0.221763  1.843988
# 609    0.215509  1.791979
# ..          ...       ...
# 160    0.115089  0.827307
# 979    0.121693  0.819309
# 764    0.111762  0.803387
# 338    0.106737  0.767269
# 529    0.142857  0.747250
#
# [397 rows x 5 columns]

# %%
sides_consequents_all.loc[sides_consequents_all.groupby('consequents')['lift'].idxmax()].sort_values(by='lift', ascending=False)
# Out:
#                                       antecedents         consequents  \
# 570        (Pork Tenderloin, Duckhorn Chardonnay)      (Caesar Salad)
# 977      (Roast Chicken, Total Recall Chardonnay)  (Roasted Potatoes)
# 862   (Oyster Bay Sauvignon Blanc, Roast Chicken)   (Mashed Potatoes)
# 1009                 (Sea Bass, Three Rivers Red)   (Warm Goat Salad)
# 439          (Salmon, Oyster Bay Sauvignon Blanc)         (Bean Trio)
# 769      (Pork Tenderloin, Echeverria Gran Syrah)      (Seasonal Veg)
# 539               (Salmon, Brancott Pinot Grigio)  (Roasted Root Veg)
#
#        support  confidence      lift
# 570   0.008172    0.230144  1.913675
# 977   0.002020    0.203704  1.577023
# 862   0.001732    0.182825  1.545159
# 1009  0.001010    0.208108  1.495965
# 439   0.003948    0.215000  1.401342
# 769   0.002965    0.257697  1.347948
# 539   0.002204    0.199525  1.343318

# %% [markdown]
# #### consequents = wines

# %%
#filtering for consequents to be wines only
wines_consequents_all = out_rules2_all[out_rules2_all['consequents'].apply(lambda x: list(x)[0] in wines)]
#sort by lift
wines_consequents_all.sort_values(by='lift', ascending=False)
# Out:
#                            antecedents             consequents   support  \
# 853      (Roasted Root Veg, Pork Chop)           (Louis Rouge)  0.002873
# 856          (Pork Chop, Seasonal Veg)           (Louis Rouge)  0.003070
# 848      (Roasted Potatoes, Pork Chop)           (Louis Rouge)  0.002230
# 858       (Warm Goat Salad, Pork Chop)           (Louis Rouge)  0.002164
# 183                        (Pork Chop)           (Louis Rouge)  0.016555
# ..                                 ...                     ...       ...
# 19                   (Warm Goat Salad)  (Adelsheim Pinot Noir)  0.016869
# 0                          (Bean Trio)  (Adelsheim Pinot Noir)  0.017919
# 304          (Caesar Salad, Pork Chop)  (Adelsheim Pinot Noir)  0.001692
# 126                    (Roast Chicken)   (Duckhorn Chardonnay)  0.005982
# 713  (Roasted Potatoes, Roast Chicken)   (Duckhorn Chardonnay)  0.001154
#
#      confidence      lift
# 853    0.120928  3.573131
# 856    0.120247  3.553009
# 848    0.118467  3.500421
# 858    0.115708  3.418910
# 183    0.114978  3.397336
# ..          ...       ...
# 19     0.121264  0.896807
# 0      0.116792  0.863738
# 304    0.108953  0.805762
# 126    0.122581  0.797124
# 713    0.120548  0.783906
#
# [276 rows x 5 columns]

# %%
wines_consequents_all.loc[wines_consequents_all.groupby('consequents')['lift'].idxmax()].sort_values(by='lift', ascending=False)
# Out:
#                              antecedents  \
# 853        (Roasted Root Veg, Pork Chop)
# 490     (Roasted Potatoes, Filet Mignon)
# 860     (Mashed Potatoes, Roast Chicken)
# 526    (Roast Chicken, Roasted Root Veg)
# 588             (Caesar Salad, Sea Bass)
# 621            (Salmon, Mashed Potatoes)
# 579         (Caesar Salad, Filet Mignon)
# 354  (Pork Tenderloin, Roasted Root Veg)
# 785      (Warm Goat Salad, Filet Mignon)
# 980        (Roast Chicken, Seasonal Veg)
# 728         (Sea Bass, Roasted Root Veg)
#
#                               consequents   support  confidence      lift
# 853                         (Louis Rouge)  0.002873    0.120928  3.573131
# 490                   (Blackstone Merlot)  0.008238    0.364481  3.274655
# 860          (Oyster Bay Sauvignon Blanc)  0.001732    0.204019  3.230103
# 526               (Brancott Pinot Grigio)  0.001246    0.188492  3.208869
# 588  (Innocent Bystander Sauvignon Blanc)  0.004237    0.251166  2.993148
# 621                (Cantina Pinot Bianco)  0.002046    0.120185  2.549264
# 579               (Echeverria Gran Syrah)  0.003345    0.146216  2.423142
# 354                (Adelsheim Pinot Noir)  0.003502    0.312646  2.312182
# 785              (Single Vineyard Malbec)  0.004696    0.232016  2.270215
# 980             (Total Recall Chardonnay)  0.001797    0.218501  2.079003
# 728                 (Duckhorn Chardonnay)  0.006821    0.270833  1.761191
